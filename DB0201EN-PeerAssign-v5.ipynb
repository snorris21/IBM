# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Census Data</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Public Schools</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in Week 3 Lab 3, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/LoadingData.png">
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the first dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new tables as follows:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# Out:
# Requirement already satisfied: sqlalchemy==1.3.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.3.9)
# Requirement already satisfied: ibm_db_sa in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.3.3)
# Requirement already satisfied: sqlalchemy>=0.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ibm_db_sa) (1.3.9)

# %%
# %load_ext sql

# %% [markdown]
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance in first lab in Week 3. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://fjq00738:pk5lkxrv%2B4rzqqcp@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Out:
# 'Connected: fjq00738@BLUDB'

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql INSERT into  CHICAGO_PUBLIC_SCHOOLS\
values ("Elementary, Middle, or High School" = "ES"))

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for all types of schools.

# %%
# %sql SELECT name_of_school, avg (safety_score) as average_safety_score\
FROM CHICAGO_PUBLIC_SCHOOLS\
GROUP BY name_of_school\
WHERE ;

# %%
# %sql select LEN (REPLACE ("Elementary, Middle, or High School" = "%ES%"))
# Out:
#  * ibm_db_sa://fjq00738:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token "END-OF-STATEMENT" was found following "h School" = "%ES%"))".  Expected tokens may include:  "<table_expr>".  SQLSTATE=42601 SQLCODE=-104
# [SQL: select LEN (REPLACE ("Elementary, Middle, or High School" = "%ES%"))]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql SELECT name_of_school, avg (safety_score) as average_safety_score\
FROM CHICAGO_PUBLIC_SCHOOLS\
GROUP BY \
WHERE ;


"Elementary, Middle, or High School"] = "ES"
"Elementary, Middle, or High School"] = "HS"
"Elementary, Middle, or High School"] = "MS"
# Out:
#  * ibm_db_sa://fjq00738:***@dashdb-txn-sbox-yp-dal09-14.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('A.N. Pritzker School', Decimal('59.000000')),
#  ('Abraham Lincoln Elementary School', Decimal('99.000000')),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', Decimal('54.000000')),
#  ('Adlai E Stevenson Elementary School', Decimal('61.000000')),
#  ('Agustin Lara Elementary Academy', Decimal('56.000000')),
#  ('Air Force Academy High School', Decimal('49.000000')),
#  ('Al Raby High School', Decimal('52.000000')),
#  ('Albany Park Multicultural Academy', Decimal('66.000000')),
#  ('Albert G Lane Technical High School', Decimal('88.000000')),
#  ('Albert R Sabin Elementary Magnet School', Decimal('67.000000')),
#  ('Alcott High School for the Humanities', Decimal('70.000000')),
#  ('Alessandro Volta Elementary School', Decimal('43.000000')),
#  ('Alex Haley Elementary Academy', Decimal('28.000000')),
#  ('Alexander Graham Bell Elementary School', Decimal('99.000000')),
#  ('Alexander Graham Elementary School', Decimal('49.000000')),
#  ('Alexander Hamilton Elementary School', Decimal('73.000000')),
#  ('Alexander von Humboldt Elementary School', Decimal('31.000000')),
#  ('Alfred David Kohn Elementary School', Decimal('19.000000')),
#  ('Alfred Nobel Elementary School', Decimal('37.000000')),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', Decimal('46.000000')),
#  ('Ambrose Plamondon Elementary School', Decimal('45.000000')),
#  ('Amelia Earhart Options for Knowledge Elementary School', Decimal('81.000000')),
#  ('Ames Middle School', Decimal('38.000000')),
#  ('Amos Alonzo Stagg Elementary School', Decimal('23.000000')),
#  ('Ana Roque de Duprey Elementary School', Decimal('57.000000')),
#  ('Andrew Carnegie Elementary School', Decimal('48.000000')),
#  ('Andrew Jackson Elementary Language Academy', Decimal('86.000000')),
#  ('Anna R. Langford Community Academy', Decimal('31.000000')),
#  ('Annie Keller Elementary Gifted Magnet School', Decimal('99.000000')),
#  ('Anthony Overton Elementary School', Decimal('32.000000')),
#  ('Ariel Elementary Community Academy', None),
#  ('Arna Wendell Bontemps Elementary School', Decimal('33.000000')),
#  ('Arnold Mireles Elementary Academy', Decimal('27.000000')),
#  ('Arthur A Libby Elementary School', Decimal('36.000000')),
#  ('Arthur Dixon Elementary School', Decimal('47.000000')),
#  ('Arthur E Canty Elementary School', Decimal('87.000000')),
#  ('Arthur R Ashe Elementary School', None),
#  ('Asa Philip Randolph Elementary School', Decimal('15.000000')),
#  ('Ashburn Community Elementary School', Decimal('48.000000')),
#  ('Augustus H Burley Elementary School', Decimal('99.000000')),
#  ('Austin Business and Entrepreneurship Academy High School', Decimal('38.000000')),
#  ('Austin O Sexton Elementary School', Decimal('23.000000')),
#  ('Austin Polytechnical Academy High School', Decimal('38.000000')),
#  ('Avalon Park Elementary School', Decimal('32.000000')),
#  ('Barbara Vick Early Childhood & Family Center', None),
#  ('Belmont-Cragin Elementary School', Decimal('75.000000')),
#  ('Benito Juarez Community Academy High School', Decimal('46.000000')),
#  ('Benjamin Banneker Elementary School', Decimal('36.000000')),
#  ('Benjamin E Mays Elementary Academy', Decimal('27.000000')),
#  ('Bernhard Moos Elementary School', Decimal('50.000000')),
#  ('Betsy Ross Elementary School', Decimal('39.000000')),
#  ('Beulah Shoesmith Elementary School', Decimal('45.000000')),
#  ('Blair Early Childhood Center', None),
#  ('Bret Harte Elementary School', Decimal('63.000000')),
#  ('Brian Piccolo Elementary Specialty School', Decimal('27.000000')),
#  ('Brighton Park Elementary School', Decimal('55.000000')),
#  ('Bronzeville Scholastic Academy High School', Decimal('41.000000')),
#  ('Burnham Elementary Inclusive Academy', Decimal('61.000000')),
#  ('Burnside Elementary Scholastic Academy', Decimal('51.000000')),
#  ('Calmeca Academy of Fine Arts and Dual Language', Decimal('58.000000')),
#  ('Carl Schurz High School', Decimal('48.000000')),
#  ('Carl von Linne Elementary School', Decimal('68.000000')),
#  ('Carrie Jacobs Bond Elementary School', Decimal('54.000000')),
#  ('Carroll-Rosenwald Specialty Elementary School', Decimal('35.000000')),
#  ('Carter G Woodson South Elementary School', Decimal('26.000000')),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', Decimal('54.000000')),
#  ('Charles Allen Prosser Career Academy High School', Decimal('59.000000')),
#  ('Charles Evans Hughes Elementary School', Decimal('42.000000')),
#  ('Charles G Hammond Elementary School', Decimal('40.000000')),
#  ('Charles Gates Dawes Elementary School', Decimal('44.000000')),
#  ('Charles H Wacker Elementary School', Decimal('32.000000')),
#  ('Charles Kozminski Elementary Community Academy', Decimal('36.000000')),
#  ('Charles N Holden Elementary School', Decimal('53.000000')),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', Decimal('25.000000')),
#  ('Charles P Steinmetz Academic Centre High School', Decimal('26.000000')),
#  ('Charles R Darwin Elementary School', Decimal('58.000000')),
#  ('Charles R Henderson Elementary School', Decimal('16.000000')),
#  ('Charles S Brownell Elementary School', Decimal('20.000000')),
#  ('Charles S Deneen Elementary School', Decimal('55.000000')),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', Decimal('41.000000')),
#  ('Charles W Earle Elementary School', Decimal('24.000000')),
#  ('Chicago Academy Elementary School', Decimal('66.000000')),
#  ('Chicago Academy High School', Decimal('58.000000')),
#  ('Chicago High School for Agricultural Sciences', Decimal('87.000000')),
#  ('Chicago Military Academy High School', Decimal('32.000000')),
#  ('Chicago Vocational Career Academy High School', Decimal('27.000000')),
#  ('Christian Ebinger Elementary School', Decimal('78.000000')),
#  ('Christian Fenger Academy High School', Decimal('36.000000')),
#  ('Christopher Columbus Elementary School', Decimal('66.000000')),
#  ('Clara Barton Elementary School', Decimal('25.000000')),
#  ('Claremont Academy Elementary School', Decimal('36.000000')),
#  ('Collins Academy High School', Decimal('60.000000')),
#  ('Columbia Explorers Elementary Academy', Decimal('59.000000')),
#  ('Countee Cullen Elementary School', Decimal('14.000000')),
#  ('Crispus Attucks Elementary School', Decimal('45.000000')),
#  ('Crown Community Academy of Fine Arts Center Elementary School', Decimal('27.000000')),
#  ('Cyrus H McCormick Elementary School', None),
#  ('Daniel Boone Elementary School', Decimal('52.000000')),
#  ('Daniel C Beard Elementary School', None),
#  ('Daniel Hale Williams Prep School of Medicine', Decimal('50.000000')),
#  ('Daniel J Corkery Elementary School', Decimal('39.000000')),
#  ('Daniel R Cameron Elementary School', Decimal('42.000000')),
#  ('Daniel S Wentworth Elementary School', Decimal('30.000000')),
#  ('Daniel Webster Elementary School', Decimal('48.000000')),
#  ('David G Farragut Career Academy High School', Decimal('43.000000')),
#  ('DeVry University Advantage Academy High School', None),
#  ('DeWitt Clinton Elementary School', Decimal('47.000000')),
#  ('Dewey Elementary Academy of Fine Arts', Decimal('41.000000')),
#  ('Disney II Magnet School', None),
#  ('Donald Morrill Math & Science Elementary School', Decimal('28.000000')),
#  ('Douglas Taylor Elementary School', Decimal('34.000000')),
#  ('Dr  Martin Luther King  Jr  College Prep High School', None),
#  ('Dr Jorge Prieto Math and Science', None),
#  ('Dumas Technology Academy', Decimal('19.000000')),
#  ('Dunne Technology Academy', Decimal('46.000000')),
#  ('Durkin Park Elementary School', Decimal('61.000000')),
#  ('Dvorak Technology Academy', Decimal('46.000000')),
#  ('Dyett High School', Decimal('27.000000')),
#  ('Edgar Allan Poe Elementary Classical School', Decimal('99.000000')),
#  ('Edgebrook Elementary School', Decimal('99.000000')),
#  ('Edison Park Elementary School', Decimal('95.000000')),
#  ('Edmond Burke Elementary School', Decimal('1.000000')),
#  ('Edward A Bouchet Math & Science Academy Elementary School', Decimal('33.000000')),
#  ('Edward Beasley Elementary Magnet Academic Center', Decimal('47.000000')),
#  ('Edward C Delano Elementary School', Decimal('38.000000')),
#  ('Edward Coles Elementary Language Academy', Decimal('22.000000')),
#  ('Edward Everett Elementary School', None),
#  ('Edward Jenner Elementary Academy of the Arts', Decimal('50.000000')),
#  ('Edward K Ellington Elementary School', Decimal('30.000000')),
#  ('Edward N Hurley Elementary School', Decimal('77.000000')),
#  ('Edward Tilden Career Community Academy High School', Decimal('34.000000')),
#  ('Edward White Elementary Career Academy', Decimal('27.000000')),
#  ('Edwin G Foreman High School', Decimal('26.000000')),
#  ('Elaine O Goodlow Elementary Magnet School', Decimal('44.000000')),
#  ('Eli Whitney Elementary School', Decimal('44.000000')),
#  ('Elihu Yale Elementary School', Decimal('29.000000')),
#  ('Eliza Chappell Elementary School', Decimal('70.000000')),
#  ('Elizabeth H Sutherland Elementary School', Decimal('86.000000')),
#  ('Elizabeth Peabody Elementary School', Decimal('51.000000')),
#  ('Ella Flagg Young Elementary School', Decimal('31.000000')),
#  ('Ellen H Richards Career Academy High School', Decimal('30.000000')),
#  ('Ellen Mitchell Elementary School', Decimal('99.000000')),
#  ('Emil G Hirsch Metropolitan High School', Decimal('13.000000')),
#  ('Emiliano Zapata Elementary Academy', Decimal('60.000000')),
#  ('Emmett Louis Till Math and Science Academy', Decimal('31.000000')),
#  ('Enrico Fermi Elementary School', Decimal('30.000000')),
#  ('Enrico Tonti Elementary School', None),
#  ('Eric Solorio Academy High School', Decimal('67.000000')),
#  ('Ernst Prussing Elementary School', Decimal('71.000000')),
#  ('Esmond Elementary School', Decimal('36.000000')),
#  ('Eugene Field Elementary School', Decimal('42.000000')),
#  ('Everett McKinley Dirksen Elementary School', Decimal('44.000000')),
#  ('Evergreen Academy Middle School', Decimal('60.000000')),
#  ('Fairfield Elementary Academy', Decimal('31.000000')),
#  ('Federico Garcia Lorca Elementary School', Decimal('53.000000')),
#  ('Ferdinand Peck Elementary School', Decimal('51.000000')),
#  ('Fernwood Elementary School', Decimal('29.000000')),
#  ('Florence B Price Elementary School', Decimal('20.000000')),
#  ('Florence Nightingale Elementary School', Decimal('35.000000')),
#  ('Fort Dearborn Elementary School', Decimal('34.000000')),
#  ('Foster Park Elementary School', Decimal('11.000000')),
#  ('Francis M McKay Elementary School', Decimal('23.000000')),
#  ('Francis Parkman Elementary School', Decimal('38.000000')),
#  ('Francis Scott Key Elementary School', Decimal('37.000000')),
#  ('Francis W Parker Elementary Community Academy', Decimal('30.000000')),
#  ('Francisco I Madero Middle School', Decimal('49.000000')),
#  ('Frank I Bennett Elementary School', Decimal('46.000000')),
#  ('Frank L Gillespie Elementary School', Decimal('27.000000')),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', Decimal('46.000000')),
#  ('Frank W Reilly Elementary School', Decimal('48.000000')),
#  ('Franklin Elementary Fine Arts Center', Decimal('87.000000')),
#  ('Franz Peter Schubert Elementary School', None),
#  ('Frazier Prospective IB Magnet Elementary School', Decimal('60.000000')),
#  ('Frederic Chopin Elementary School', Decimal('86.000000')),
#  ('Frederick A Douglass Academy High School', Decimal('44.000000')),
#  ('Frederick Funston Elementary School', Decimal('16.000000')),
#  ('Frederick Stock Elementary School', None),
#  ('Friedrich Ludwig Jahn Elementary School', Decimal('72.000000')),
#  ('Friedrich W von Steuben Metropolitan Science High School', Decimal('70.000000')),
#  ('Gage Park High School', Decimal('14.000000')),
#  ('Galileo Math & Science Scholastic Academy Elementary School', Decimal('65.000000')),
#  ('Garrett A Morgan Elementary School', Decimal('28.000000')),
#  ('Genevieve Melody Elementary School', Decimal('61.000000')),
#  ('George Armstrong International Studies Elementary School', Decimal('59.000000')),
#  ('George B McClellan Elementary School', Decimal('49.000000')),
#  ('George B Swift Elementary Specialty School', Decimal('61.000000')),
#  ('George F Cassell Elementary School', Decimal('76.000000')),
#  ('George H Corliss High School', Decimal('33.000000')),
#  ('George Leland Elementary School', None),
#  ('George M Pullman Elementary School', Decimal('59.000000')),
#  ('George Manierre Elementary School', Decimal('43.000000')),
#  ('George Rogers Clark Elementary School', Decimal('39.000000')),
#  ('George W Curtis Elementary School', Decimal('23.000000')),
#  ('George W Tilton Elementary School', Decimal('6.000000')),
#  ('George Washington Carver Military Academy High School', Decimal('53.000000')),
#  ('George Washington Carver Primary School', Decimal('25.000000')),
#  ('George Washington Elementary School', Decimal('58.000000')),
#  ('George Washington High School', Decimal('46.000000')),
#  ('George Westinghouse High School', Decimal('74.000000')),
#  ('Gerald Delgado Kanoon Elementary Magnet School', Decimal('44.000000')),
#  ('Graeme Stewart Elementary School', Decimal('49.000000')),
#  ('Granville T Woods Math & Science Academy Elementary School', Decimal('35.000000')),
#  ('Greater Lawndale High School For Social Justice', Decimal('43.000000')),
#  ('Grover Cleveland Elementary School', Decimal('64.000000')),
#  ('Guglielmo Marconi Elementary Community Academy', Decimal('26.000000')),
#  ('Gurdon S Hubbard High School', Decimal('42.000000')),
#  ('Gwendolyn Brooks College Preparatory Academy High School', Decimal('64.000000')),
#  ('Hannah G Solomon Elementary School', Decimal('78.000000')),
#  ('Hanson Park Elementary School', Decimal('35.000000')),
#  ('Harold Washington Elementary School', Decimal('28.000000')),
#  ('Harriet Beecher Stowe Elementary School', Decimal('28.000000')),
#  ('Harriet E Sayre Elementary Language Academy', Decimal('68.000000')),
#  ('Hawthorne Elementary Scholastic Academy', Decimal('92.000000')),
#  ('Helen M Hefferan Elementary School', Decimal('29.000000')),
#  ('Helen Peirce International Studies Elementary School', Decimal('58.000000')),
#  ('Helge A Haugan Elementary School', Decimal('43.000000')),
#  ('Henry Clay Elementary School', Decimal('38.000000')),
#  ('Henry D Lloyd Elementary School', None),
#  ('Henry H Nash Elementary School', Decimal('41.000000')),
#  ('Henry O Tanner Elementary School', Decimal('33.000000')),
#  ('Henry R Clissold Elementary School', Decimal('45.000000')),
#  ('High School of Leadership at South Shore', None),
#  ('Hiram H Belding Elementary School', Decimal('64.000000')),
#  ('Hope College Preparatory High School', Decimal('31.000000')),
#  ('Horace Greeley Elementary School', Decimal('65.000000')),
#  ('Horace Mann Elementary School', Decimal('28.000000')),
#  ('Horatio May Elementary Community Academy', Decimal('42.000000')),
#  ('Hyde Park Academy High School', Decimal('29.000000')),
#  ('Hyman G Rickover Naval Academy High School', Decimal('64.000000')),
#  ('Ida B Wells Preparatory Elementary Academy', Decimal('49.000000')),
#  ('Ignance Paderewski Elementary Learning Academy', Decimal('31.000000')),
#  ('Infinity Math Science and Technology High School', Decimal('58.000000')),
#  ('Inter-American Elementary Magnet School', Decimal('67.000000')),
#  ('Ira F Aldridge Elementary School', Decimal('39.000000')),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', Decimal('34.000000')),
#  ('Irma C Ruiz Elementary School', Decimal('57.000000')),
#  ('Irvin C Mollison Elementary School', Decimal('44.000000')),
#  ("Isabelle C O'Keeffe Elementary School", Decimal('17.000000')),
#  ('Jackie Robinson Elementary School', None),
#  ('Jacob Beidler Elementary School', Decimal('63.000000')),
#  ('Jacqueline B Vaughn Occupational High School', Decimal('57.000000')),
#  ('James B Farnsworth Elementary School', Decimal('55.000000')),
#  ('James B McPherson Elementary School', Decimal('71.000000')),
#  ('James E McDade Elementary Classical School', Decimal('99.000000')),
#  ('James G Blaine Elementary School', Decimal('99.000000')),
#  ('James Hedges Elementary School', Decimal('22.000000')),
#  ('James Madison Elementary School', Decimal('39.000000')),
#  ('James Monroe Elementary School', Decimal('45.000000')),
#  ('James N Thorp Elementary School', Decimal('32.000000')),
#  ('James Otis Elementary School', Decimal('83.000000')),
#  ('James R Doolittle Jr Elementary School', Decimal('30.000000')),
#  ('James Russell Lowell Elementary School', Decimal('39.000000')),
#  ('James Shields Elementary School', Decimal('38.000000')),
#  ('James Wadsworth Elementary School', None),
#  ('James Ward Elementary School', Decimal('49.000000')),
#  ('James Weldon Johnson Elementary School', Decimal('67.000000')),
#  ('Jane A Neil Elementary School', Decimal('42.000000')),
#  ('Jane Addams Elementary School', Decimal('56.000000')),
#  ('Jean Baptiste Beaubien Elementary School', Decimal('63.000000')),
#  ('Jean D Lafayette Elementary School', Decimal('44.000000')),
#  ('Jensen Elementary Scholastic Academy', Decimal('35.000000')),
#  ('Jesse Owens Elementary Community Academy', None),
#  ('Jesse Sherwood Elementary School', Decimal('38.000000')),
#  ('Johann W von Goethe Elementary School', Decimal('75.000000')),
#  ('John A Walsh Elementary School', Decimal('60.000000')),
#  ('John B Drake Elementary School', Decimal('59.000000')),
#  ('John B Murphy Elementary School', Decimal('80.000000')),
#  ('John Barry Elementary School', Decimal('35.000000')),
#  ('John C Burroughs Elementary School', Decimal('50.000000')),
#  ('John C Coonley Elementary School', Decimal('87.000000')),
#  ('John C Dore Elementary School', Decimal('74.000000')),
#  ('John Calhoun North Elementary School', Decimal('52.000000')),
#  ('John Charles Haines Elementary School', Decimal('32.000000')),
#  ('John D Shoop Math-Science Technical Academy Elementary School', Decimal('32.000000')),
#  ('John F Eberhart Elementary School', Decimal('42.000000')),
#  ('John F Kennedy High School', Decimal('53.000000')),
#  ('John Fiske Elementary School', Decimal('13.000000')),
#  ('John Foster Dulles Elementary School', Decimal('42.000000')),
#  ('John Greenleaf Whittier Elementary School', Decimal('65.000000')),
#  ('John H Hamline Elementary School', Decimal('33.000000')),
#  ('John H Kinzie Elementary School', Decimal('64.000000')),
#  ('John H Vanderpoel Elementary Magnet School', Decimal('74.000000')),
#  ('John Hancock College Preparatory High School', Decimal('51.000000')),
#  ('John Harvard Elementary School of Excellence', Decimal('51.000000')),
#  ('John Hay Elementary Community Academy', Decimal('44.000000')),
#  ('John J Audubon Elementary School', Decimal('95.000000')),
#  ('John J Pershing Elementary Humanities Magnet', None),
#  ('John L Marsh Elementary School', Decimal('72.000000')),
#  ('John M Harlan Community Academy High School', None),
#  ('John M Smyth Elementary School', Decimal('37.000000')),
#  ('John Marshall Metropolitan High School', Decimal('51.000000')),
#  ('John Milton Gregory Elementary School', Decimal('44.000000')),
#  ('John P Altgeld Elementary School', Decimal('48.000000')),
#  ('John Palmer Elementary School', Decimal('75.000000')),
#  ('John Spry Elementary Community School', Decimal('66.000000')),
#  ('John T McCutcheon Elementary School', Decimal('56.000000')),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', Decimal('26.000000')),
#  ('John W Cook Elementary School', None),
#  ('John W Garvy Elementary School', Decimal('60.000000')),
#  ('John Whistler Elementary School', Decimal('45.000000')),
#  ('Johnnie Colemon Elementary Academy', Decimal('60.000000')),
#  ('Jonathan Burr Elementary School', Decimal('71.000000')),
#  ('Jonathan Y Scammon Elementary School', Decimal('44.000000')),
#  ('Jordan Elementary Community School', Decimal('61.000000')),
#  ('Jose De Diego Elementary Community Academy', Decimal('57.000000')),
#  ('Josefa Ortiz De Dominguez Elementary School', None),
#  ('Joseph Brennemann Elementary School', Decimal('50.000000')),
#  ('Joseph E Gary Elementary School', Decimal('32.000000')),
#  ('Joseph Jungman Elementary School', Decimal('36.000000')),
#  ('Joseph Kellman Corporate Community Elementary School', Decimal('58.000000')),
#  ('Joseph Lovett Elementary School', Decimal('43.000000')),
#  ('Joseph Stockton Elementary School', Decimal('37.000000')),
#  ('Joseph Warren Elementary School', Decimal('33.000000')),
#  ('Josephine C Locke Elementary School', Decimal('57.000000')),
#  ('Joshua D Kershaw Elementary School', Decimal('62.000000')),
#  ('Josiah Pickard Elementary School', Decimal('50.000000')),
#  ('Joyce Kilmer Elementary School', None),
#  ('Julia C Lathrop Elementary School', Decimal('67.000000')),
#  ('Julia Ward Howe Elementary School of Excellence', Decimal('67.000000')),
#  ('Kate S Buckingham Special Education Center', Decimal('31.000000')),
#  ('Kate S Kellogg Elementary School', Decimal('76.000000')),
#  ('Kelvyn Park High School', Decimal('32.000000')),
#  ('Kenwood Academy High School', Decimal('63.000000')),
#  ('LaSalle Elementary Language Academy', Decimal('99.000000')),
#  ('LaSalle II Magnet Elementary School', Decimal('66.000000')),
#  ('Lake View High School', Decimal('64.000000')),
#  ('Langston Hughes Elementary School', Decimal('28.000000')),
#  ('Laughlin Falconer Elementary School', Decimal('54.000000')),
#  ('Laura S Ward Elementary School', None),
#  ('Lawndale Elementary Community Academy', None),
#  ('Lazaro Cardenas Elementary School', None),
#  ('Leif Ericson Elementary Scholastic Academy', Decimal('33.000000')),
#  ('Lenart Elementary Regional Gifted Center', Decimal('79.000000')),
#  ('Leslie Lewis Elementary School', Decimal('21.000000')),
#  ('Lincoln Park High School', Decimal('65.000000')),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', Decimal('42.000000')),
#  ('Little Village Elementary School', Decimal('45.000000')),
#  ('Logandale Middle School', Decimal('56.000000')),
#  ('Lorenz Brentano Math & Science Academy Elementary School', Decimal('57.000000')),
#  ('Louis A Agassiz Elementary School', Decimal('53.000000')),
#  ('Louis Armstrong Math & Science Elementary School', Decimal('42.000000')),
#  ('Louis Nettelhorst Elementary School', Decimal('58.000000')),
#  ('Louis Pasteur Elementary School', Decimal('50.000000')),
#  ('Louisa May Alcott Elementary School', None),
#  ('Ludwig Van Beethoven Elementary School', Decimal('40.000000')),
#  ("Luke O'Toole Elementary School", Decimal('5.000000')),
#  ('Luther Burbank Elementary School', Decimal('37.000000')),
#  ('Lyman A Budlong Elementary School', Decimal('59.000000')),
#  ('Lyman Trumbull Elementary School', Decimal('56.000000')),
#  ('Mahalia Jackson Elementary School', Decimal('38.000000')),
#  ('Mancel Talcott Elementary School', Decimal('63.000000')),
#  ('Manley Career Academy High School', Decimal('41.000000')),
#  ('Manuel Perez Elementary School', Decimal('45.000000')),
#  ('Marcus Moziah Garvey Elementary School', Decimal('50.000000')),
#  ('Maria Saucedo Elementary Scholastic Academy', Decimal('60.000000')),
#  ('Mariano Azuela Elementary School', Decimal('54.000000')),
#  ('Marie Sklodowska Curie Metropolitan High School', Decimal('43.000000')),
#  ('Marine Military Math and Science Academy', Decimal('41.000000')),
#  ('Mark Sheridan Elementary Math & Science Academy', Decimal('74.000000')),
#  ('Mark Skinner Elementary School', Decimal('87.000000')),
#  ('Mark Twain Elementary School', Decimal('67.000000')),
#  ('Marquette Elementary School', Decimal('15.000000')),
#  ('Martha Ruggles Elementary School', Decimal('43.000000')),
#  ('Martin A Ryerson Elementary School', Decimal('40.000000')),
#  ('Marvin Camras Elementary School', Decimal('54.000000')),
#  ('Mary E Courtenay Elementary Language Arts Center', Decimal('99.000000')),
#  ('Mary E McDowell Elementary School', None),
#  ('Mary Gage Peterson Elementary School', Decimal('62.000000')),
#  ('Mary Lyon Elementary School', Decimal('55.000000')),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', Decimal('57.000000')),
#  ('Mary McLeod Bethune Elementary School', Decimal('53.000000')),
#  ('Mason High School', Decimal('50.000000')),
#  ('Matthew A Henson Elementary School', Decimal('37.000000')),
#  ('Matthew Gallistel Elementary Language Academy', Decimal('49.000000')),
#  ('Medgar Evers Elementary School', Decimal('27.000000')),
#  ('Melville W Fuller Elementary School', Decimal('22.000000')),
#  ('Michael Faraday Elementary School', Decimal('35.000000')),
#  ('Michael M Byrne Elementary School', Decimal('63.000000')),
#  ('Michele Clark Academic Prep Magnet High School', None),
#  ('Mildred I Lavizzo Elementary School', Decimal('15.000000')),
#  ('Milton Brunson Math & Science Specialty Elementary School', Decimal('30.000000')),
#  ('Minnie Mars Jamieson Elementary School', Decimal('64.000000')),
#  ('Miriam G Canter Middle School', Decimal('57.000000')),
#  ('Morgan Park High School', Decimal('40.000000')),
#  ('Morton School of Excellence', Decimal('53.000000')),
#  ('Moses Montefiore Special Elementary School', Decimal('28.000000')),
#  ('Mount Greenwood Elementary School', Decimal('84.000000')),
#  ('Mount Vernon Elementary School', Decimal('31.000000')),
#  ('Multicultural Academy of Scholarship', Decimal('48.000000')),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', Decimal('31.000000')),
#  ('Nathan Hale Elementary School', Decimal('55.000000')),
#  ('Nathan R Goldblatt Elementary School', Decimal('49.000000')),
#  ('Nathan S Davis Elementary School', Decimal('43.000000')),
#  ('Nathanael Greene Elementary School', None),
#  ('Nathaniel Pope Elementary School', Decimal('48.000000')),
#  ('National Teachers Elementary Academy', Decimal('67.000000')),
#  ('Neal F Simeon Career Academy High School', Decimal('52.000000')),
#  ('Near North Elementary School', Decimal('50.000000')),
#  ('New Field Elementary School', None),
#  ('New Millennium High School of Health at Bowen', Decimal('17.000000')),
#  ('Newton Bateman Elementary School', Decimal('55.000000')),
#  ('Nicholas Senn High School', Decimal('48.000000')),
#  ('Nicholson Technology Academy', Decimal('48.000000')),
#  ('Ninos Heroes Elementary Academic Center', Decimal('36.000000')),
#  ('Norman A Bridge Elementary School', Decimal('67.000000')),
#  ('North River Elementary School', Decimal('67.000000')),
#  ('North-Grand High School', Decimal('42.000000')),
#  ('Northside College Preparatory High School', Decimal('99.000000')),
#  ('Northside Learning Center High School', Decimal('99.000000')),
#  ('Northwest Middle School', Decimal('34.000000')),
#  ('Norwood Park Elementary School', Decimal('99.000000')),
#  ('Ogden International High School', Decimal('56.000000')),
#  ('Ole A Thorp Elementary Scholastic Academy', Decimal('70.000000')),
#  ('Oliver S Westcott Elementary School', Decimal('30.000000')),
#  ('Oliver Wendell Holmes Elementary School', Decimal('21.000000')),
#  ('Oriole Park Elementary School', Decimal('99.000000')),
#  ('Orozco Fine Arts & Sciences Elementary School', Decimal('55.000000')),
#  ('Orr Academy High School', None),
#  ('Orville T Bright Elementary School', Decimal('18.000000')),
#  ('Oscar DePriest Elementary School', Decimal('35.000000')),
#  ('Oscar F Mayer Elementary School', Decimal('67.000000')),
#  ('Pablo Casals Elementary School', None),
#  ('Park Manor Elementary School', Decimal('28.000000')),
#  ('Parkside Elementary Community Academy', None),
#  ('Patrick Henry Elementary School', Decimal('45.000000')),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', Decimal('51.000000')),
#  ('Paul Laurence Dunbar Career Academy High School', Decimal('29.000000')),
#  ('Paul Revere Elementary School', Decimal('36.000000')),
#  ('Paul Robeson High School', Decimal('29.000000')),
#  ('Percy L Julian High School', Decimal('28.000000')),
#  ('Perkins Bass Elementary School', Decimal('28.000000')),
#  ('Pershing West Middle School', Decimal('46.000000')),
#  ('Peter A Reinberg Elementary School', Decimal('60.000000')),
#  ('Peter Cooper Elementary Dual Language Academy', None),
#  ('Philip Rogers Elementary School', Decimal('81.000000')),
#  ('Phillip D Armour Elementary School', Decimal('36.000000')),
#  ('Phillip Murray Elementary Language Academy', Decimal('66.000000')),
#  ('Phobe Apperson Hearst Elementary School', Decimal('33.000000')),
#  ('Phoenix Military Academy High School', Decimal('53.000000')),
#  ('Pilsen Elementary Community Academy', Decimal('43.000000')),
#  ('Portage Park Elementary School', Decimal('62.000000')),
#  ('Pulaski International Academy Elmentary School', Decimal('68.000000')),
#  ('Rachel Carson Elementary School', Decimal('38.000000')),
#  ('Ralph H Metcalfe Elementary Community Academy', None),
#  ('Ravenswood Elementary School', Decimal('46.000000')),
#  ('Ray Graham Training Center High School', Decimal('90.000000')),
#  ('Richard Edwards Elementary School', Decimal('48.000000')),
#  ('Richard Henry Lee Elementary School', Decimal('59.000000')),
#  ('Richard J Daley Elementary Academy', Decimal('29.000000')),
#  ('Richard J Oglesby Elementary School', Decimal('44.000000')),
#  ('Richard T Crane Technical Preparatory High School', Decimal('43.000000')),
#  ('Richard Yates Elementary School', Decimal('42.000000')),
#  ('Roald Amundsen High School', Decimal('51.000000')),
#  ('Robert A Black Magnet Elementary School', Decimal('68.000000')),
#  ('Robert Emmet Elementary School', Decimal('37.000000')),
#  ('Robert Fulton Elementary School', Decimal('46.000000')),
#  ('Robert H Lawrence Elementary School', Decimal('19.000000')),
#  ('Robert Healy Elementary School', Decimal('63.000000')),
#  ('Robert L Grimes Elementary School', Decimal('79.000000')),
#  ('Robert Lindblom Math & Science Academy High School', Decimal('66.000000')),
#  ('Robert Nathaniel Dett Elementary School', Decimal('48.000000')),
#  ('Roberto Clemente Community Academy High School', Decimal('44.000000')),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', Decimal('55.000000')),
#  ('Roger C Sullivan High School', Decimal('30.000000')),
#  ('Ronald Brown Elementary Community Academy', Decimal('31.000000')),
#  ('Ronald E McNair Elementary School', Decimal('31.000000')),
#  ('Rosario Castellanos Elementary School', Decimal('36.000000')),
#  ('Roswell B Mason Elementary School', Decimal('37.000000')),
#  ('Rudyard Kipling Elementary School', Decimal('52.000000')),
#  ('Rueben Salazar Elementary Bilingual Center', Decimal('64.000000')),
#  ('Rufus M Hitch Elementary School', Decimal('64.000000')),
#  ('Salmon P Chase Elementary School', Decimal('55.000000')),
#  ('Samuel Gompers Fine Arts Options Elementary School', Decimal('34.000000')),
#  ('Sauganash Elementary School', Decimal('99.000000')),
#  ('Scott Joplin Elementary School', Decimal('35.000000')),
#  ('Sharon Christa McAuliffe Elementary School', None),
#  ('Sidney Sawyer Elementary School', Decimal('57.000000')),
#  ('Simon Guggenheim Elementary School', Decimal('30.000000')),
#  ('Sir Miles Davis Magnet Elementary Academy', Decimal('35.000000')),
#  ('Skinner North', None),
#  ('Socorro Sandoval Elementary School', None),
#  ('Songhai Elementary Learning Institute', Decimal('17.000000')),
#  ('South Loop Elementary School', Decimal('84.000000')),
#  ('South Shore Fine Arts Academy', None),
#  ('Southside Occupational Academy High School', None),
#  ('Spencer Technology Academy', Decimal('35.000000')),
#  ('Spry Community Links High School', Decimal('70.000000')),
#  ('Stephen Decatur Classical Elementary School', Decimal('99.000000')),
#  ('Stephen F Gale Elementary Community Academy', Decimal('39.000000')),
#  ('Stephen K Hayt Elementary School', Decimal('72.000000')),
#  ('Stephen T Mather High School', Decimal('58.000000')),
#  ('Stone Elementary Scholastic Academy', Decimal('78.000000')),
#  ('Suder Montessori Magnet Elementary School', None),
#  ('TEAM Englewood Community Academy High School', Decimal('45.000000')),
#  ('Talman Elementary School', Decimal('99.000000')),
#  ('Tarkington School of Excellence Elementary School', Decimal('48.000000')),
#  ('Telpochcalli Elementary School', Decimal('42.000000')),
#  ('Theodore Herzl Elementary School', Decimal('41.000000')),
#  ('Theodore Roosevelt High School', Decimal('42.000000')),
#  ('Theophilus Schmid Elementary School', Decimal('46.000000')),
#  ('Thomas A Edison Regional Gifted Center Elementary School', Decimal('91.000000')),
#  ('Thomas A Hendricks Elementary Community Academy', Decimal('33.000000')),
#  ('Thomas Chalmers Specialty Elementary School', Decimal('34.000000')),
#  ('Thomas Drummond Elementary School', Decimal('72.000000')),
#  ('Thomas Hoyne Elementary School', Decimal('67.000000')),
#  ('Thomas J Higgins Elementary Community Academy', None),
#  ('Thomas J Waters Elementary School', Decimal('85.000000')),
#  ('Thomas Kelly High School', Decimal('36.000000')),
#  ('Thurgood Marshall Middle School', Decimal('39.000000')),
#  ('Turner-Drew Elementary Language Academy', Decimal('56.000000')),
#  ('Uplift Community High School', Decimal('50.000000')),
#  ('VOISE Academy High School', Decimal('42.000000')),
#  ('Velma F Thomas Early Childhood Center', None),
#  ('Victor Herbert Elementary School', Decimal('50.000000')),
#  ('Virgil Grissom Elementary School', Decimal('62.000000')),
#  ('Walt Disney Magnet Elementary School', None),
#  ('Walter L Newberry Math & Science Academy Elementary School', Decimal('71.000000')),
#  ('Walter Payton College Preparatory High School', Decimal('98.000000')),
#  ('Walter Q Gresham Elementary School', Decimal('25.000000')),
#  ('Walter Reed Elementary School', Decimal('29.000000')),
#  ('Walter S Christopher Elementary School', None),
#  ('Washington D Smyser Elementary School', Decimal('55.000000')),
#  ('Washington Irving Elementary School', Decimal('43.000000')),
#  ('Wells Community Academy High School', Decimal('51.000000')),
#  ('Wendell E Green Elementary School', Decimal('32.000000')),
#  ('Wendell Phillips Academy High School', None),
#  ('Wendell Smith Elementary School', Decimal('22.000000')),
#  ('West Park Elementary Academy', Decimal('29.000000')),
#  ('West Pullman Elementary School', Decimal('23.000000')),
#  ('West Ridge Elementary School', Decimal('67.000000')),
#  ('Whitney M Young Magnet High School', Decimal('95.000000')),
#  ('Wildwood Elementary School', Decimal('99.000000')),
#  ('Willa Cather Elementary School', Decimal('69.000000')),
#  ('William A Hinton Elementary School', Decimal('18.000000')),
#  ('William B Ogden Elementary School', None),
#  ('William Bishop Owen Scholastic Academy Elementary School', Decimal('49.000000')),
#  ('William C Goudy Elementary School', Decimal('70.000000')),
#  ('William C Reavis Math & Science Specialty Elementary School', Decimal('48.000000')),
#  ('William E B Dubois Elementary School', Decimal('47.000000')),
#  ('William E Dever Elementary School', Decimal('67.000000')),
#  ('William F Finkl Elementary School', Decimal('56.000000')),
#  ('William G Hibbard Elementary School', None),
#  ('William H Brown Elementary School', Decimal('36.000000')),
#  ('William H King Elementary School', Decimal('47.000000')),
#  ('William H Prescott Elementary School', Decimal('90.000000')),
#  ('William H Ray Elementary School', Decimal('69.000000')),
#  ('William H Ryder Math & Science Specialty Elementary School', Decimal('34.000000')),
#  ('William H Seward Communication Arts Academy Elementary School', Decimal('40.000000')),
#  ('William Howard Taft High School', Decimal('61.000000')),
#  ('William J & Charles H Mayo Elementary School', Decimal('52.000000')),
#  ('William J Bogan High School', Decimal('20.000000')),
#  ('William J Onahan Elementary School', Decimal('64.000000')),
#  ('William Jones College Preparatory High School', Decimal('92.000000')),
#  ('William K New Sullivan Elementary School', Decimal('27.000000')),
#  ('William P Gray Elementary School', Decimal('57.000000')),
#  ('William P Nixon Elementary School', Decimal('52.000000')),
#  ('William Penn Elementary School', Decimal('78.000000')),
#  ('William Rainey Harper High School', Decimal('22.000000')),
#  ('William T Sherman Elementary School', Decimal('32.000000')),
#  ('William W Carter Elementary School', Decimal('13.000000')),
#  ('Williams Multiplex Elementary School', None),
#  ('Williams Preparatory Academy Middle School', Decimal('49.000000')),
#  ('Wilma Rudolph Elementary Learning Center', None),
#  ('Wolfgang A Mozart Elementary School', Decimal('41.000000')),
#  ('Woodlawn Community Elementary School', Decimal('70.000000')),
#  ('World Language Academy High School', Decimal('51.000000'))]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %% [markdown]
# Copyright © 2020 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
